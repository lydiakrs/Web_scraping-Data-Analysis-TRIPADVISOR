# %%
import pandas as pd
import numpy as np
# %matplotlib inline
import matplotlib.pyplot as plt
import seaborn as sns
sns.set(color_codes = True)

# %% [markdown]
# # lecture csv

# %%
df = pd.read_csv('restaurants2.csv')

# %%
df
# Out:
#                         commentaire_1  \
# 0    “AMBIANCE VILLA: AN EXOTIC FEEL”
# 1                     “Faded but fun”
# 2                     “Great seafood”
# 3               “Best Gelato in Oran”
# 4                      “Indian Taste”
# ..                                ...
# 116                               NaN
# 117                               NaN
# 118                               NaN
# 119                               NaN
# 120                               NaN
#
#                                     commentaire_2                    genre  \
# 0    “an Eden - a Culinary delight - Exceptional”  Mediterranean, European
# 1                           “Dinner with friends”         French, European
# 2               “Top de top frégate oran Algérie”   Seafood, Mediterranean
# 3                          “Best Ice Cream Ever!”         Dessert, Italian
# 4                       “Good tasty Indian food.”                   Indian
# ..                                            ...                      ...
# 116                                           NaN     American, Steakhouse
# 117                                           NaN                  Dessert
# 118                                           NaN         French, American
# 119                                           NaN                 Algerian
# 120                                           NaN                 European
#
#     mesure_de_securite                         nom  note      prix   rang  \
# 0                  NaN           Ambiance La Villa   4.5  $$ - $$$    1.0
# 1                  NaN                   La Comete   4.0  $$ - $$$    2.0
# 2                  NaN                  La Fregate   4.5         $    3.0
# 3                  NaN              Vanille Fraise   4.5         $    4.0
# 4                  NaN  Maharaja Indian Restaurant   4.0  $$ - $$$    5.0
# ..                 ...                         ...   ...       ...    ...
# 116                NaN                  Sky Lounge   NaN       NaN  117.0
# 117                NaN                 MIZA Gelato   NaN       NaN  118.0
# 118                NaN   Lunchbox By Sheraton Oran   NaN  $$ - $$$  119.0
# 119                NaN             Sunset Canastel   NaN       NaN  120.0
# 120                NaN              Au Fin Gourmet   NaN       NaN  121.0
#
#      total_commentaire
# 0                151.0
# 1                152.0
# 2                 51.0
# 3                 53.0
# 4                109.0
# ..                 ...
# 116                NaN
# 117                NaN
# 118                NaN
# 119                NaN
# 120                NaN
#
# [121 rows x 9 columns]

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 121 entries, 0 to 120
# Data columns (total 9 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   commentaire_1       90 non-null     object
#  1   commentaire_2       76 non-null     object
#  2   genre               95 non-null     object
#  3   mesure_de_securite  3 non-null      object
#  4   nom                 121 non-null    object
#  5   note                90 non-null     float64
#  6   prix                72 non-null     object
#  7   rang                121 non-null    float64
#  8   total_commentaire   90 non-null     float64
# dtypes: float64(3), object(6)
# memory usage: 8.6+ KB

# %%
restaurants = df[['rang','nom','note','genre','prix','total_commentaire','mesure_de_securite','commentaire_1','commentaire_2']]

restaurants
# Out:
#       rang                         nom  note                    genre  \
# 0      1.0           Ambiance La Villa   4.5  Mediterranean, European
# 1      2.0                   La Comete   4.0         French, European
# 2      3.0                  La Fregate   4.5   Seafood, Mediterranean
# 3      4.0              Vanille Fraise   4.5         Dessert, Italian
# 4      5.0  Maharaja Indian Restaurant   4.0                   Indian
# ..     ...                         ...   ...                      ...
# 116  117.0                  Sky Lounge   NaN     American, Steakhouse
# 117  118.0                 MIZA Gelato   NaN                  Dessert
# 118  119.0   Lunchbox By Sheraton Oran   NaN         French, American
# 119  120.0             Sunset Canastel   NaN                 Algerian
# 120  121.0              Au Fin Gourmet   NaN                 European
#
#          prix  total_commentaire mesure_de_securite  \
# 0    $$ - $$$              151.0                NaN
# 1    $$ - $$$              152.0                NaN
# 2           $               51.0                NaN
# 3           $               53.0                NaN
# 4    $$ - $$$              109.0                NaN
# ..        ...                ...                ...
# 116       NaN                NaN                NaN
# 117       NaN                NaN                NaN
# 118  $$ - $$$                NaN                NaN
# 119       NaN                NaN                NaN
# 120       NaN                NaN                NaN
#
#                         commentaire_1  \
# 0    “AMBIANCE VILLA: AN EXOTIC FEEL”
# 1                     “Faded but fun”
# 2                     “Great seafood”
# 3               “Best Gelato in Oran”
# 4                      “Indian Taste”
# ..                                ...
# 116                               NaN
# 117                               NaN
# 118                               NaN
# 119                               NaN
# 120                               NaN
#
#                                     commentaire_2
# 0    “an Eden - a Culinary delight - Exceptional”
# 1                           “Dinner with friends”
# 2               “Top de top frégate oran Algérie”
# 3                          “Best Ice Cream Ever!”
# 4                       “Good tasty Indian food.”
# ..                                            ...
# 116                                           NaN
# 117                                           NaN
# 118                                           NaN
# 119                                           NaN
# 120                                           NaN
#
# [121 rows x 9 columns]

# %% [markdown]
# # valeurs manquantes par colonne

# %%
missing_values = restaurants.isnull()
sns.heatmap(data=missing_values, cmap='viridis')
# Out:
# <AxesSubplot:>

# %% [markdown]
# # les restaurants prennent ils ou pas des mesures de sécurité?

# %%
restaurants['mesure_de_securite'] = restaurants['mesure_de_securite'].fillna('sans mesure de sécurité')

# %%
restaurants['mesure_de_securite'].value_counts().plot.pie(radius = 2, autopct='%1.1f%%', explode=(0,1), startangle=0)
plt.axes().set_ylabel('')
plt.title(' les restaurants prennent ils ou pas des mesures de sécurité?', pad = 80, fontsize = 15)
# Out:
# <ipython-input-8-970dc56bd816>:2: MatplotlibDeprecationWarning: Adding an axes using the same arguments as a previous axes currently reuses the earlier instance.  In a future version, a new instance will always be created and returned.  Meanwhile, this warning can be suppressed, and the future behavior ensured, by passing a unique label to each axes instance.
#   plt.axes().set_ylabel('')
# Text(0.5, 1.0, ' les restaurants prennent ils ou pas des mesures de sécurité?')

# %% [markdown]
# # Nombre de restaurants par note

# %%
restaurants['note'].value_counts()
# Out:
# 4.0    27
# 5.0    18
# 4.5    16
# 3.5    14
# 3.0     7
# 2.5     6
# 1.0     2
# Name: note, dtype: int64

# %%
#nb restau par tranche de prix
restaurants['prix'].value_counts()
# Out:
# $$ - $$$    34
# $           30
# $$$$         8
# Name: prix, dtype: int64

# %%
price_map = {'$': 1, '$$ - $$$': 2, '$$$$': 3}
restaurants['prix'] = restaurants['prix'].map(price_map, na_action='ignore')

# %%
restaurants['prix'].value_counts()
# Out:
# 2.0    34
# 1.0    30
# 3.0     8
# Name: prix, dtype: int64

# %%
price_order = [1.0,2.0,3.0]
p = sns.countplot(x = "prix", data = restaurants, order = price_order)
p.set_xticklabels(['Pas cher','Moyen','Cher'])
p.set_title('Répartition des prix des restaurants', fontsize = 15)
# Out:
# Text(0.5, 1.0, 'Répartition des prix des restaurants')

# %% [markdown]
# # le restaurant avec le plus de commentaires

# %%
restaurants[restaurants['total_commentaire'] == restaurants['total_commentaire'].max()]
# Out:
#    rang               nom  note            genre  prix  total_commentaire  \
# 8   9.0  Le Mediterraneen   4.0  French, Seafood   2.0              262.0
#
#         mesure_de_securite    commentaire_1  commentaire_2
# 8  sans mesure de sécurité  “Give it a try”  “Fish galore”

# %% [markdown]
# # liste du top 10 restaurants par note et pas nombre de commentaires

# %%
restaurants.sort_values(['total_commentaire','note'],ascending=[False, False]).head(10)
# Out:
#     rang                         nom  note                    genre  prix  \
# 8    9.0            Le Mediterraneen   4.0          French, Seafood   2.0
# 1    2.0                   La Comete   4.0         French, European   2.0
# 0    1.0           Ambiance La Villa   4.5  Mediterranean, European   2.0
# 5    6.0                 Bekhchi ' S   4.0  Mediterranean, European   2.0
# 4    5.0  Maharaja Indian Restaurant   4.0                   Indian   2.0
# 10  11.0              Le Ciel D'Oran   3.5                      NaN   3.0
# 12  13.0           Restaurant Cintra   3.5                Gastropub   2.0
# 3    4.0              Vanille Fraise   4.5         Dessert, Italian   1.0
# 2    3.0                  La Fregate   4.5   Seafood, Mediterranean   1.0
# 9   10.0                    It Side.   4.0                      NaN   2.0
#
#     total_commentaire       mesure_de_securite  \
# 8               262.0  sans mesure de sécurité
# 1               152.0  sans mesure de sécurité
# 0               151.0  sans mesure de sécurité
# 5               140.0  sans mesure de sécurité
# 4               109.0  sans mesure de sécurité
# 10               71.0  sans mesure de sécurité
# 12               63.0  sans mesure de sécurité
# 3                53.0  sans mesure de sécurité
# 2                51.0  sans mesure de sécurité
# 9                42.0  sans mesure de sécurité
#
#                                    commentaire_1  \
# 8                                “Give it a try”
# 1                                “Faded but fun”
# 0               “AMBIANCE VILLA: AN EXOTIC FEEL”
# 5   “Great Place to experience Mediterranean...”
# 4                                 “Indian Taste”
# 10                  “this was an average please”
# 12        “reopened Feb 2014. Good stab at a...”
# 3                          “Best Gelato in Oran”
# 2                                “Great seafood”
# 9                                 “Turkish Food”
#
#                                    commentaire_2
# 8                                  “Fish galore”
# 1                          “Dinner with friends”
# 0   “an Eden - a Culinary delight - Exceptional”
# 5                                       “To try”
# 4                      “Good tasty Indian food.”
# 10                                   “very good”
# 12                           “Lovely restaurant”
# 3                         “Best Ice Cream Ever!”
# 2              “Top de top frégate oran Algérie”
# 9    “I loved the place a lot! It's a family...”
